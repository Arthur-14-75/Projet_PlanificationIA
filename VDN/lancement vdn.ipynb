# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Udes/PIA/VDN
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Udes/PIA/VDN

# %%
# Installation de l'écran virtuel pour la capture vidéo
# !apt-get update > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install pyvirtualdisplay

# Installe tes librairies RL (à adapter selon tes besoins)
# !pip install torch tensorboard pettingzoo supersuit ale_py

# %%
# !pip install "pettingzoo[atari,accept-rom-license]" multi-agent-ale-py
# Out:
# ...
# WARNING: pettingzoo 1.25.0 does not provide the extra 'accept-rom-license'
# ...

# %%
! pip install "AutoROM[accept-rom-license]"

# %%
! AutoROM --accept-license
# Out:
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
# 	/usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms
#
# Existing ROMs will be overwritten.

# %%
#!xvfb-run -a python vdn_test.py \
#  --episodes 10000 \
#  --batch-size 32 \
#  --buffer-size 50000 \
#  --max-steps 1000 \
#  --checkpoint-every 500 \
#  --checkpoint-dir checkpoints/vdn_ice_hockey \
#  --tb-logdir runs/vdn_hockey_exp_1 \
#  --video-eval --video-every 500 --video-dir videos/vdn_ice_hockey \
#  --eval-episodes 3 \
#  --device cuda

# %%
  #!xvfb-run -a python vdn_test.py \
  #--episodes 10000 \
  #--batch-size 32 \
  #--buffer-size 30000 \
  #--max-steps 1000 \
  #--checkpoint-every 500 \
  #--checkpoint-dir checkpoints/vdn_ice_hockey \
  #--tb-logdir runs/vdn_hockey_exp_1 \
  #--device cuda \
  #--video-eval --video-every 500 --video-dir videos/vdn_ice_hockey \
  #--eval-episodes 3 \
  #--eps-decay-steps 700000 \
  #--load-checkpoint checkpoints/vdn_ice_hockey/modele_vdn_ep_500.pth
# Out:
# 2026-04-08 13:58:06.249251: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775656686.272211    5679 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775656686.279863    5679 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775656686.298549    5679 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !xvfb-run -a python vdn_test.py \
  --episodes 5400 \
  --batch-size 32 \
  --buffer-size 30000 \
  --max-steps 1000 \
  --checkpoint-every 100 \
  --checkpoint-dir checkpoints/vdn_ice_hockey \
  --tb-logdir runs/vdn_hockey_exp_1 \
  --device cuda \
  --video-eval --video-every 100 --video-dir videos/vdn_ice_hockey \
  --eval-episodes 3 \
  --eps-start 0.05 \
  --load-checkpoint checkpoints/vdn_ice_hockey/modele_vdn_ep_4400.pth
# Out:
# 2026-04-10 20:57:20.005278: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775854640.027633   25364 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775854640.034694   25364 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775854640.052966   25364 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !load_ext tensorboard
# !tensorboard --logdir runs/vdn_hockey_exp_1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().system('load_ext tensorboard')
#       2 get_ipython().system('tensorboard --logdir runs/vdn_hockey_exp_1')
#
# File /opt/anaconda3/envs/ia_env/lib/python3.11/site-packages/ipykernel/zmqshell.py:788, in ZMQInteractiveShell.system_piped(self, cmd)
#     786         self.user_ns["_exit_code"] = system(cmd)
#     787 else:
# --> 788     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File /opt/anaconda3/envs/ia_env/lib/python3.11/site-packages/IPython/utils/_process_posix.py:98, in ProcessHandler.system(self, cmd)
#      86 def system(self, cmd: str) -> int:
#      87     """Execute a command in a subshell.
#      88
#      89     Parameters
#    (...)     96     int : child's exitstatus
#      97     """
# ---> 98     import pexpect
# ...

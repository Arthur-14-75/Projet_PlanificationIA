# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Projet
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Projet

# %%
# Installation de l'écran virtuel pour la capture vidéo
# !apt-get update > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install pyvirtualdisplay
# !apt-get update
# !apt-get install -y ffmpeg xvfb

# Installe tes librairies RL (à adapter selon tes besoins)
# !pip install torch tensorboard pettingzoo supersuit ale_py
# Out:
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (3,224 B/s)
# Reading package lists... Done
# ...

# %%
# !pip install "pettingzoo[atari,accept-rom-license]" multi-agent-ale-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 552.0/552.0 kB 36.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# WARNING: pettingzoo 1.25.0 does not provide the extra 'accept-rom-license'
# ...
#   Created wheel for multi-agent-ale-py: filename=multi_agent_ale_py-0.1.11-cp312-cp312-linux_x86_64.whl size=721822 sha256=e983d3d0f98d5f057c1d97ac0cdd6e9c965070291ebc784fd5c4480a9e282cdf
#   Stored in directory: /root/.cache/pip/wheels/e8/3a/b7/07e61057dae117a8c0943263e0e88e2fa71d95b285720ff9e1
# Successfully built multi-agent-ale-py
# ...

# %%
! pip install "AutoROM[accept-rom-license]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 27.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=a5975e1569a025082a24e65a8210cc58f7b5d7baca2df35d5c0ab7cd6c418dc5
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# ...

# %%
! AutoROM --accept-license
# Out:
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
# 	/usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms
#
# Existing ROMs will be overwritten.
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/adventure.bin
# Installed /usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms/adventure.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/air_raid.bin
# Installed /usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms/air_raid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/alien.bin
# Installed /usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms/alien.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/amidar.bin
# Installed /usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms/amidar.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/assault.bin
# ...

# %%
#!xvfb-run -a python vdn_test.py \
#  --episodes 10000 \
#  --batch-size 32 \
#  --buffer-size 30000 \
#  --max-steps 1000 \
#  --checkpoint-every 100 \
#  --checkpoint-dir checkpoints/vdn_ice_hockey \
#  --tb-logdir runs/vdn_hockey_exp_1 \
#  --device cuda \
#  --video-eval --video-every 100 --video-dir videos/vdn_ice_hockey \
#  --eval-episodes 3 \
#  --eps-decay-steps 700000 \
#  --load-checkpoint checkpoints/vdn_ice_hockey/modele_vdn_ep_1500.pth

# %%
# !xvfb-run -a python vdn_test_amélioré.py --episodes 5700 \
  --batch-size 32 \
  --buffer-size 100000 \
  --max-steps 1000 \
  --checkpoint-every 10 \
  --checkpoint-dir checkpoints/vdn_ice_hockey \
  --tb-logdir runs/vdn_hockey_exp_1 \
  --device cuda \
  --video-eval --video-every 500 --video-dir videos/vdn_ice_hockey \
  --eval-episodes 5 \
  --eps-start 0.07 \
  --eps-decay-steps 100000 \
  --load-checkpoint checkpoints/vdn_ice_hockey/modele_vdn_ep_5510.pth \
  --num-envs 4
# Out:
# 2026-04-13 00:08:27.250794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776038907.274120   17113 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776038907.281051   17113 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776038907.302604   17113 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

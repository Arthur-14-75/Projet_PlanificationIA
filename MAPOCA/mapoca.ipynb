# %% [markdown]
# # Implémentation de l'algorithme MA-POCA sur ICE Hockey

# %% [markdown]
# ## Chargement du jeu

# %%
import supersuit as ss
import gymnasium as gym
from pettingzoo.atari import ice_hockey_v2

def target_env():
    env = ice_hockey_v2.env()
    env = ss.color_reduction_v0(env, mode='grey')
    env.reset()
    env = ss.resize(env, x_size=84, y_size=84)
    env = ss.frame_stack_v1(env, 4)
    return env

# %% [markdown]
# ## Réseau de neurones pour l'encodage des observations

# %%
from observation_encoding import Residual_block
from observation_encoding import Impala_Layer
from observation_encoding import Impala_CNN
import torch

def sanity_check_impala():
    #paramètres
    batch_size = 8
    input_shape = (4, 84, 84) # 4 frames stacked, 84x84 pixels
    feature_dim = 512

    #initialisation du modèle

    impala_model = Impala_CNN(input_shape=input_shape, feature_dim=feature_dim)

    # Création d'un batch de tests

    sample_input = torch.randn(batch_size, *input_shape)  # (batch_size, channels, height, width)

    print(f"--- Sanity Check Impala CNN ---")
    print(f"Entrée du batch : {sample_input.shape}") # [8, 4, 84, 84]

    #Propagation avant

    try:
        with torch.no_grad():
            output = impala_model(sample_input)

        print(f"Sortie du batch : {output.shape}") # [8, 512]

        assert output.shape == (batch_size, feature_dim), f"Expected output shape {(batch_size, feature_dim)}, but got {output.shape}"
        assert not torch.isnan(output).any(), "Output contains NaN values"

        print("Résultat du sanity check : SUCCESS")
    
    except Exception as e:
        print(f"Résultat du sanity check : FAILURE - {str(e)}")

# %%
sanity_check_impala()
# Out:
# --- Sanity Check Impala CNN ---
# Entrée du batch : torch.Size([8, 4, 84, 84])
# Sortie du batch : torch.Size([8, 512])
# Résultat du sanity check : SUCCESS

# %% [markdown]
# Test de validité du gradient

# %%
def check_gradient_flow(impala_model):

    batch_size = 8
    x = torch.randn(batch_size, 4, 84, 84)
    target = torch.randn(batch_size, 512) #sortie attendue

    # propagation avant + loss

    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(impala_model.parameters(), lr=1e-4)

    output = impala_model(x)
    loss = criterion(output, target)

    # propagation arrière

    optimizer.zero_grad()
    loss.backward()

    # vérification des gradients

    has_grad = True
    for name, param in impala_model.named_parameters():
        if param.grad is None:
            print(f"Paramètre {name} n'a pas de gradient.")
            has_grad = False
        elif torch.all(param.grad == 0):
            print(f"⚠️ Gradient nul pour {name}")
            has_grad = False
    
    if has_grad:
        print("✅ Flux de gradient détecté sur tous les paramètres.")

    old_weights = impala_model.layer1.conv.weight.clone()
    optimizer.step()
    new_weights = impala_model.layer1.conv.weight.clone()

    if not torch.equal(old_weights, new_weights):
        print("✅ Les poids ont été mis à jour après l'optimizer.step().")

# %% [markdown]
# Affichage des courbes d'apprentissage et de loss

# %%
import matplotlib.pyplot as plt

def plot_training_curves(impala_model, num_epoch=100):

    # fixer la cible pour la reproductibilité

    torch.manual_seed(42)

    optimizer = torch.optim.Adam(impala_model.parameters(), lr=1e-3)
    criterion = torch.nn.MSELoss()

    # données fixes pour forcer le surapprentissage

    x_train = torch.randint(0, 256, (16, 4, 84, 84)).float() # (batch_size, channels, height, width)
    y_train = torch.randn(16, 512) # (batch_size, feature_dim)

    x_val = torch.randint(0, 256, (8, 4, 84, 84)).float()
    y_val = torch.randn(8, 512)

    train_history = []
    val_history = []

    print("Début du test d'overfitting...")

    for epoch in range(num_epoch):

        # Entraînement
        impala_model.train()
        optimizer.zero_grad()
        output = impala_model(x_train)
        loss = criterion(output, y_train)
        loss.backward()
        optimizer.step()
        train_history.append(loss.item())

        # Evaluation

        impala_model.eval()
        with torch.no_grad():
            val_output = impala_model(x_val)
            val_loss = criterion(val_output, y_val)
            val_history.append(val_loss.item())
        
        if epoch % 20 == 0:
            print(f"Époque {epoch}: Train Loss {loss.item():.4f} | Val Loss {val_loss.item():.4f}")
    
    # Affichage des courbes

    plt.figure(figsize=(9, 4))
    plt.plot(train_history, label='Train Loss (Overfitting Target)')
    plt.plot(val_history, label='Validation Loss (Generalization Test)', linestyle='--')
    plt.yscale('log')
    plt.xlabel('Époques')
    plt.ylabel('MSE Loss')
    plt.title('Sanity Check : Capacité d\'apprentissage vs Généralisation')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
impala_model = Impala_CNN(input_shape=(4, 84, 84), feature_dim=512)
check_gradient_flow(impala_model)
plot_training_curves(impala_model, num_epoch=50)
# Out:
# ✅ Flux de gradient détecté sur tous les paramètres.
# ✅ Les poids ont été mis à jour après l'optimizer.step().
# Début du test d'overfitting...
# Époque 0: Train Loss 0.9950 | Val Loss 1.0005
# Époque 20: Train Loss 0.9221 | Val Loss 1.0385
# Époque 40: Train Loss 0.7758 | Val Loss 1.0905

# %% [markdown]
# on a bien de l'overfitting sur notre petit batch de données, les poids sont bien mis à jours après chaque itération. Donc notre Impala CNN fonctionne

# %% [markdown]
# ## Implémentation du module Residual-Self-Attention

# %%
from RSA import RSAModule

def sanity_check_rsa():
    batch_size = 8
    num_agents = 2
    feature_dim = 512

    rsa = RSAModule(feature_dim=feature_dim, num_heads=4)

    # on simule la sortie de 2 Impala_CNN pour 2 agents

    simulated_features = torch.randn(batch_size, num_agents, feature_dim) # (batch_size, num_agents, feature_dim)

    output = rsa(simulated_features)

    print(f"Entrée RSA (Agents empilés) : {simulated_features.shape}")
    print(f"Sortie RSA : {output.shape}")

    assert output.shape == (batch_size, num_agents, feature_dim)
    print("✅ Le module RSA traite correctement les interactions entre agents.")

# %%
sanity_check_rsa()
# Out:
# Entrée RSA (Agents empilés) : torch.Size([8, 2, 512])
# Sortie RSA : torch.Size([8, 2, 512])
# ✅ Le module RSA traite correctement les interactions entre agents.

# %% [markdown]
# # Implémentation du module Centralized Critics

# %%
from centralized_critic import Centralized_critic

critic = Centralized_critic(num_agents=2)

# 2. Simulation d'observations pour 2 agents (batch de 4)
observation_1 = torch.randn(4, 4, 84, 84)
observation_2 = torch.randn(4, 4, 84, 84)

# 3. Appel explicite de forward pour déboguer le 'callable'
# En PyTorch, critic(obs) appelle automatiquement forward(obs).
try:
    values = critic.forward([observation_1, observation_2])
    print(f"Succès ! Forme des valeurs prédites : {values.shape}") 
    # Doit être [4, 2]
except Exception as e:
    print(f"Erreur lors de l'appel : {e}")
# Out:
# Succès ! Forme des valeurs prédites : torch.Size([4, 2])

# %%
from actor import MultiAgentActors

def sanity_check_actors():
    batch_size = 4
    action_dim = 18

    # Initialisation
    actor = MultiAgentActors(action_dim=action_dim)

    # Simulation d'observations (Batch de 4 frames empilées)
    observation = torch.randn(batch_size, 4, 84, 84)
    
    print("--- Sanity Check Actor ---")

    # test du forward

    logits = actor(observation)
    print(f"Logits shape : {logits.shape}") # Doit être [4, 18]
    assert logits.shape == (batch_size ,action_dim)

    # Test de get_action(stochastique)

    actions_random = actor.get_action(observation, deterministic=False)
    print(f"Actions (stochastiques) : {actions_random}")

    # Test de get_action(déterministe)

    action_deterministic = actor.get_action(observation, deterministic=True)
    print(f"Actions (déterministes) : {action_deterministic}")

    assert actions_random.shape == (batch_size,)
    assert action_deterministic.shape == (batch_size,)

    print("✅ L'Actor fonctionne : il transforme les images en actions valides.")

# %%
sanity_check_actors()
# Out:
# --- Sanity Check Actor ---
# Logits shape : torch.Size([4, 18])
# Actions (stochastiques) : tensor([14, 16,  0,  7])
# Actions (déterministes) : tensor([2, 2, 2, 2])
# ✅ L'Actor fonctionne : il transforme les images en actions valides.

# %% [markdown]
# Ici on veut vérifier si le système de récompense fonctionne bien

# %%
from reward_system import puck_position, RewardSystem

import matplotlib.pyplot as plt

# on récupère une image du jeu 
env = target_env()
env.reset()

obs, _, _, _, _ = env.last()

detector = puck_position()
coords = detector.get_puck_position(obs)

plt.figure(figsize=(8, 6))
plt.imshow(obs)

if coords:
    cX, cY = coords
    plt.scatter(cX, cY, s=100, c='red', marker='x', label=f"Palet détecté ({cX}, {cY})")
    print(f"Succès ! Palet trouvé aux coordonnées : {coords}")
else:
    print("Le palet n'a pas été détecté. Vérifie les seuils de couleur.")

plt.title("Test du détecteur visuel de palet")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/lambda_wrappers/observation_lambda.py:61, in aec_observation_lambda.observation_space(self, agent)
#      60 try:
# ---> 61     return self.change_obs_space_fn(old_obs_space, agent)
#      62 except TypeError:
#
# TypeError: basic_obs_wrapper.<locals>.change_space() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 6
#       3 import matplotlib.pyplot as plt
#       5 # on récupère une image du jeu
# ----> 6 env = target_env()
#       7 env.reset()
#       9 obs, _, _, _, _ = env.last()
#
# Cell In[1], line 7, in target_env()
#       5 def target_env():
#       6     env = ice_hockey_v2.env()
# ----> 7     env = ss.color_reduction_v0(env, mode='grey')
#       8     env.reset()
#       9     env = ss.resize(env, x_size=84, y_size=84)
#
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/generic_wrappers/basic_wrappers.py:25, in color_reduction_v0(env, mode)
#      24 def color_reduction_v0(env, mode="full"):
# ---> 25     return basic_obs_wrapper(env, basic_transforms.color_reduction, mode)
#
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/generic_wrappers/basic_wrappers.py:21, in basic_obs_wrapper(env, module, param)
#      18 def change_obs(obs, obs_space):
#      19     return module.change_observation(obs, obs_space, param)
# ---> 21 return observation_lambda_v0(env, change_obs, change_space)
#
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/utils/wrapper_chooser.py:24, in WrapperChooser.__call__(self, env, *args, **kwargs)
#      22 elif isinstance(env, AECEnv):
#      23     if self.aec_wrapper is not None:
# ---> 24         return self.aec_wrapper(env, *args, **kwargs)
#      25     else:
#      26         return parallel_to_aec(
#      27             self.parallel_wrapper(aec_to_parallel(env), *args, **kwargs)
#      28         )
#
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/lambda_wrappers/observation_lambda.py:32, in aec_observation_lambda.__init__(self, env, change_observation_fn, change_obs_space_fn)
#      29 if hasattr(self, "possible_agents"):
#      30     for agent in self.possible_agents:
#      31         # call any validation logic in this function
# ---> 32         self.observation_space(agent)
#
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/lambda_wrappers/observation_lambda.py:63, in aec_observation_lambda.observation_space(self, agent)
#      61     return self.change_obs_space_fn(old_obs_space, agent)
#      62 except TypeError:
# ---> 63     return self.change_obs_space_fn(old_obs_space)
#
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/generic_wrappers/basic_wrappers.py:14, in basic_obs_wrapper.<locals>.change_space(space)
#      13 def change_space(space):
# ---> 14     module.check_param(space, param)
#      15     space = module.change_obs_space(space, param)
#      16     return space
#
# File ~/anaconda3/lib/python3.12/site-packages/supersuit/utils/basic_transforms/color_reduction.py:14, in check_param(space, color_reduction)
#      10 def check_param(space, color_reduction):
#      11     assert isinstance(
#      12         color_reduction, str
#      13     ), f"color_reduction must be str. It is {color_reduction}"
# ---> 14     assert color_reduction in COLOR_RED_LIST, "color_reduction must be in {}".format(
#      15         COLOR_RED_LIST
#      16     )
#      17     assert (
#      18         len(space.low.shape) == 3 and space.low.shape[2] == 3
#      19     ), "To apply color_reduction, shape must be a 3d image with last dimension of size 3. Shape is {}".format(
#      20         space.low.shape
#      21     )
#
# AssertionError: color_reduction must be in ['full', 'R', 'G', 'B']
